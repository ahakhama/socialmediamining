# %%
import bs4 as bs
import urllib.request

source = urllib.request.urlopen('https://pythonprogramming.net/parsememcparseface').read()

# turns into bs object that we can interact with.0
soup = bs.BeautifulSoup(source, 'lxml')

#for p in soup.find_all('p'):
 #   print (p.text)
# print(soup.find_all('td'))

for tr in soup.find_all("tr"):
    td = tr.find_all('td')
    row = [i.text for i in td]
    print(row)

    # for table in soup.find_all("tr"):
  #  print (table.text)

# print(soup.get_text())
# Out:
# []
# ['Python', '932914021', 'Definitely']
# ['Pascal', '532', 'Unlikely']
# ['Lisp', '1522', 'Uncertain']
# ['D#', '12', 'Possibly']
# ['Cobol', '3', 'No.']
# ['Fortran', '52124', 'Yes.']
# ['Haskell', '24', 'lol.']

# %%
source = urllib.request.urlopen('http://www.vgchartz.com/preorders/43338/USA/')
soup = bs.BeautifulSoup(source, 'lxml')
for tr in soup.find_all(["tr","td/tr"]):
    td = tr.find_all('td')
    row = [i.text for i in td]
    print(row)
# Out:
# []
# ['1', '\n\n\n\nSpider-Man (PS4) (PS4)Sony Interactive Entertainment, Action-Adventure\n\n\n', '', 'Spider-Man (PS4) (PS4)Sony Interactive Entertainment, Action-Adventure', '2', '13,142', '295,073']
# ['', 'Spider-Man (PS4) (PS4)Sony Interactive Entertainment, Action-Adventure']
# ['2', '\n\n\n\nSuper Smash Bros. (2018) (NS)Nintendo, Fighting\n\n\n', '', 'Super Smash Bros. (2018) (NS)Nintendo, Fighting', '15', '29,610', '272,702']
# ['', 'Super Smash Bros. (2018) (NS)Nintendo, Fighting']
# ['3', '\n\n\n\nRed Dead Redemption 2 (PS4)Rockstar Games, Action-Adventure\n\n\n', '', 'Red Dead Redemption 2 (PS4)Rockstar Games, Action-Adventure', '9', '6,474', '253,289']
# ['', 'Red Dead Redemption 2 (PS4)Rockstar Games, Action-Adventure']
# ['4', '\n\n\n\nRed Dead Redemption 2 (XOne)Rockstar Games, Action-Adventure\n\n\n', '', 'Red Dead Redemption 2 (XOne)Rockstar Games, Action-Adventure', '9', '3,330', '176,801']
# ['', 'Red Dead Redemption 2 (XOne)Rockstar Games, Action-Adventure']
# ['5', '\n\n\n\nKingdom Hearts III (PS4)Square Enix, Role-Playing\n\n\n', '', 'Kingdom Hearts III (PS4)Square Enix, Role-Playing', '23', '3,744', '169,742']
# ['', 'Kingdom Hearts III (PS4)Square Enix, Role-Playing']
# ['6', '\n\n\n\nCall of Duty: Black Ops IIII (PS4)Activision, Shooter\n\n\n', '', 'Call of Duty: Black Ops IIII (PS4)Activision, Shooter', '7', '3,587', '139,810']
# ['', 'Call of Duty: Black Ops IIII (PS4)Activision, Shooter']
# ['7', '\n\n\n\nDays Gone (PS4)Sony Interactive Entertainment, Action\n\n\n', '', 'Days Gone (PS4)Sony Interactive Entertainment, Action', '26', '420', '117,581']
# ['', 'Days Gone (PS4)Sony Interactive Entertainment, Action']
# ['8', '\n\n\n\nNBA 2K19 (PS4)2K Sports, Sports\n\n\n', '', 'NBA 2K19 (PS4)2K Sports, Sports', '3', '17,528', '98,070']
# ['', 'NBA 2K19 (PS4)2K Sports, Sports']
# ['9', '\n\n\n\nDead Island 2 (PS4)Deep Silver, Action\n\n\n', '', 'Dead Island 2 (PS4)Deep Silver, Action', '19', '176', '90,075']
# ['', 'Dead Island 2 (PS4)Deep Silver, Action']
# ['10', '\n\n\n\nSpyro Reignited Trilogy (PS4)Activision, Platform\n\n\n', '', 'Spyro Reignited Trilogy (PS4)Activision, Platform', '12', '2,541', '89,721']
# ['', 'Spyro Reignited Trilogy (PS4)Activision, Platform']
# ['11', '\n\n\n\nCall of Duty: Black Ops IIII (XOne)Activision, Shooter\n\n\n', '', 'Call of Duty: Black Ops IIII (XOne)Activision, Shooter', '7', '3,318', '79,006']
# ['', 'Call of Duty: Black Ops IIII (XOne)Activision, Shooter']
# ['12', '\n\n\n\nSuper Mario Party (NS)Nintendo, Party\n\n\n', '', 'Super Mario Party (NS)Nintendo, Party', '6', '15,686', '56,562']
# ['', 'Super Mario Party (NS)Nintendo, Party']
# ['13', '\n\n\n\nShadow of the Tomb Raider (PS4)Square Enix, Action-Adventure\n\n\n', '', 'Shadow of the Tomb Raider (PS4)Square Enix, Action-Adventure', '3', '4,655', '50,557']
# ['', 'Shadow of the Tomb Raider (PS4)Square Enix, Action-Adventure']
# ['14', '\n\n\n\nNBA 2K19 (XOne)2K Sports, Sports\n\n\n', '', 'NBA 2K19 (XOne)2K Sports, Sports', '2', '14,636', '48,703']
# ['', 'NBA 2K19 (XOne)2K Sports, Sports']
# ['15', '\n\n\n\nFinal Fantasy VII Remake (PS4)Square Enix, Role-Playing\n\n\n', '', 'Final Fantasy VII Remake (PS4)Square Enix, Role-Playing', 'N/A', '47,543', '47,543']
# ['', 'Final Fantasy VII Remake (PS4)Square Enix, Role-Playing']
# ['16', '\n\n\n\nKingdom Hearts III (XOne)Square Enix, Role-Playing\n\n\n', '', 'Kingdom Hearts III (XOne)Square Enix, Role-Playing', '23', '356', '44,582']
# ['', 'Kingdom Hearts III (XOne)Square Enix, Role-Playing']
# ['17', '\n\n\n\nNaruto to Boruto: Shinobi Striker (PS4)Bandai Namco Games, Action\n\n\n', '', 'Naruto to Boruto: Shinobi Striker (PS4)Bandai Namco Games, Action', '1', '922', '37,724']
# ['', 'Naruto to Boruto: Shinobi Striker (PS4)Bandai Namco Games, Action']
# ['18', '\n\n\n\nMega Man 11 (NS)Capcom, Platform\n\n\n', '', 'Mega Man 11 (NS)Capcom, Platform', '6', '2,001', '37,561']
# ['', 'Mega Man 11 (NS)Capcom, Platform']
# ['19', '\n\n\n\nFallout 76 (PS4)Bethesda Softworks, Role-Playing\n\n\n', '', 'Fallout 76 (PS4)Bethesda Softworks, Role-Playing', '12', '2,311', '37,249']
# ['', 'Fallout 76 (PS4)Bethesda Softworks, Role-Playing']
# ['20', '\n\n\n\nResident Evil 2 (PS4)Capcom, Action-Adventure\n\n\n', '', 'Resident Evil 2 (PS4)Capcom, Action-Adventure', '22', '6,453', '36,910']
# ['', 'Resident Evil 2 (PS4)Capcom, Action-Adventure']
# ['21', "\n\n\n\nPokémon: Let's Go, Pikachu! (NS)Nintendo, Role-Playing\n\n\n", '', "Pokémon: Let's Go, Pikachu! (NS)Nintendo, Role-Playing", '12', '5,620', '31,651']
# ['', "Pokémon: Let's Go, Pikachu! (NS)Nintendo, Role-Playing"]
# ['22', '\n\n\n\nFallout 76 (XOne)Bethesda Softworks, Role-Playing\n\n\n', '', 'Fallout 76 (XOne)Bethesda Softworks, Role-Playing', '12', '2,011', '31,601']
# ['', 'Fallout 76 (XOne)Bethesda Softworks, Role-Playing']
# ['23', '\n\n\n\nDark Souls: Remastered (NS)Bandai Namco Entertainment, Role-Playing\n\n\n', '', 'Dark Souls: Remastered (NS)Bandai Namco Entertainment, Role-Playing', '8', '977', '31,303']
# ['', 'Dark Souls: Remastered (NS)Bandai Namco Entertainment, Role-Playing']
# ['24', '\n\n\n\nDarksiders III (PS4)THQ Nordic, Action\n\n\n', '', 'Darksiders III (PS4)THQ Nordic, Action', '14', '755', '31,216']
# ['', 'Darksiders III (PS4)THQ Nordic, Action']
# ['25', '\n\n\n\nNaruto to Boruto: Shinobi Striker (XOne)Bandai Namco Games, Action\n\n\n', '', 'Naruto to Boruto: Shinobi Striker (XOne)Bandai Namco Games, Action', '1', '492', '30,560']
# ['', 'Naruto to Boruto: Shinobi Striker (XOne)Bandai Namco Games, Action']
# ['26', '\n\n\n\nSoulCalibur VI (PS4)Bandai Namco Games, Fighting\n\n\n', '', 'SoulCalibur VI (PS4)Bandai Namco Games, Fighting', '8', '2,441', '28,911']
# ['', 'SoulCalibur VI (PS4)Bandai Namco Games, Fighting']
# ['27', '\n\n\n\nAce Combat 7: Skies Unknown (XOne)Bandai Namco Games, Shooter\n\n\n', '', 'Ace Combat 7: Skies Unknown (XOne)Bandai Namco Games, Shooter', '19', '65', '28,626']
# ['', 'Ace Combat 7: Skies Unknown (XOne)Bandai Namco Games, Shooter']
# ['28', '\n\n\n\nYakuza Kiwami 2 (PS4)Sega, Action\n\n\n', '', 'Yakuza Kiwami 2 (PS4)Sega, Action', '1', '2,391', '27,693']
# ['', 'Yakuza Kiwami 2 (PS4)Sega, Action']
# ['29', '\n\n\n\nAce Combat 7: Skies Unknown (PS4)Bandai Namco Games, Shooter\n\n\n', '', 'Ace Combat 7: Skies Unknown (PS4)Bandai Namco Games, Shooter', '19', '190', '26,902']
# ['', 'Ace Combat 7: Skies Unknown (PS4)Bandai Namco Games, Shooter']
# ['30', '\n\n\n\nMonster Hunter Double Cross (NS)Capcom, Action\n\n\n', '', 'Monster Hunter Double Cross (NS)Capcom, Action', '1', '5,642', '26,750']
# ['', 'Monster Hunter Double Cross (NS)Capcom, Action']
# ['31', '\n\n\n\nDarksiders III (XOne)THQ Nordic, Action\n\n\n', '', 'Darksiders III (XOne)THQ Nordic, Action', '14', '453', '25,306']
# ['', 'Darksiders III (XOne)THQ Nordic, Action']
# ['32', '\n\n\n\nMetro Exodus (PS4)Deep Silver, Shooter\n\n\n', '', 'Metro Exodus (PS4)Deep Silver, Shooter', '26', '790', '23,199']
# ['', 'Metro Exodus (PS4)Deep Silver, Shooter']
# ['33', '\n\n\n\nMetro Exodus (XOne)Deep Silver, Shooter\n\n\n', '', 'Metro Exodus (XOne)Deep Silver, Shooter', '26', '772', '22,646']
# ['', 'Metro Exodus (XOne)Deep Silver, Shooter']
# ['34', '\n\n\n\nShadow of the Tomb Raider (XOne)Square Enix, Action-Adventure\n\n\n', '', 'Shadow of the Tomb Raider (XOne)Square Enix, Action-Adventure', '3', '2,581', '21,971']
# ['', 'Shadow of the Tomb Raider (XOne)Square Enix, Action-Adventure']
# ['35', '\n\n\n\nDragon Quest XI (PS4)Square Enix, Role-Playing\n\n\n', '', 'Dragon Quest XI (PS4)Square Enix, Role-Playing', '2', '2,490', '21,946']
# ['', 'Dragon Quest XI (PS4)Square Enix, Role-Playing']
# ['36', '\n\n\n\nMetroid Prime 4 (NS)Nintendo, Action\n\n\n', '', 'Metroid Prime 4 (NS)Nintendo, Action', '19', '21,365', '21,365']
# ['', 'Metroid Prime 4 (NS)Nintendo, Action']
# ['37', '\n\n\n\nSpyro Reignited Trilogy (XOne)Activision, Platform\n\n\n', '', 'Spyro Reignited Trilogy (XOne)Activision, Platform', '12', '653', '20,474']
# ['', 'Spyro Reignited Trilogy (XOne)Activision, Platform']
# ['38', "\n\n\n\nPokémon: Let's Go, Eevee! (NS)Nintendo, Role-Playing\n\n\n", '', "Pokémon: Let's Go, Eevee! (NS)Nintendo, Role-Playing", '12', '3,144', '18,817']
# ['', "Pokémon: Let's Go, Eevee! (NS)Nintendo, Role-Playing"]
# ['39', "\n\n\n\nAssassin's Creed Odyssey (PS4)Ubisoft, Action-Adventure\n\n\n", '', "Assassin's Creed Odyssey (PS4)Ubisoft, Action-Adventure", '6', '3,211', '16,656']
# ['', "Assassin's Creed Odyssey (PS4)Ubisoft, Action-Adventure"]
# ['40', '\n\n\n\nValkyria Chronicles 4 (PS4)Sega, Role-Playing\n\n\n', '', 'Valkyria Chronicles 4 (PS4)Sega, Role-Playing', '5', '442', '15,404']
# ['', 'Valkyria Chronicles 4 (PS4)Sega, Role-Playing']
# []
# ['1', '\n                  \n                    \n                      \n                      Spider-Man (PS4) (PS4)Sony Interactive Entertainment, Action-Adventure\n                    \n                  \n                ', '', 'Spider-Man (PS4) (PS4)Sony Interactive Entertainment, Action-Adventure', '2', '13,142', '295,073']
# ['', 'Spider-Man (PS4) (PS4)Sony Interactive Entertainment, Action-Adventure']
# ['2', '\n                  \n                    \n                      \n                      Super Smash Bros. (2018) (NS)Nintendo, Fighting\n                    \n                  \n                ', '', 'Super Smash Bros. (2018) (NS)Nintendo, Fighting', '15', '29,610', '272,702']
# ['', 'Super Smash Bros. (2018) (NS)Nintendo, Fighting']
# ['3', '\n                  \n                    \n                      \n                      Red Dead Redemption 2 (PS4)Rockstar Games, Action-Adventure\n                    \n                  \n                ', '', 'Red Dead Redemption 2 (PS4)Rockstar Games, Action-Adventure', '9', '6,474', '253,289']
# ['', 'Red Dead Redemption 2 (PS4)Rockstar Games, Action-Adventure']
# ['4', '\n                  \n                    \n                      \n                      Red Dead Redemption 2 (XOne)Rockstar Games, Action-Adventure\n                    \n                  \n                ', '', 'Red Dead Redemption 2 (XOne)Rockstar Games, Action-Adventure', '9', '3,330', '176,801']
# ['', 'Red Dead Redemption 2 (XOne)Rockstar Games, Action-Adventure']
# ['5', '\n                  \n                    \n                      \n                      Kingdom Hearts III (PS4)Square Enix, Role-Playing\n                    \n                  \n                ', '', 'Kingdom Hearts III (PS4)Square Enix, Role-Playing', '23', '3,744', '169,742']
# ['', 'Kingdom Hearts III (PS4)Square Enix, Role-Playing']
# ['6', '\n                  \n                    \n                      \n                      Call of Duty: Black Ops IIII (PS4)Activision, Shooter\n                    \n                  \n                ', '', 'Call of Duty: Black Ops IIII (PS4)Activision, Shooter', '7', '3,587', '139,810']
# ['', 'Call of Duty: Black Ops IIII (PS4)Activision, Shooter']
# ['7', '\n                  \n                    \n                      \n                      Days Gone (PS4)Sony Interactive Entertainment, Action\n                    \n                  \n                ', '', 'Days Gone (PS4)Sony Interactive Entertainment, Action', '26', '420', '117,581']
# ['', 'Days Gone (PS4)Sony Interactive Entertainment, Action']
# ['8', '\n                  \n                    \n                      \n                      NBA 2K19 (PS4)2K Sports, Sports\n                    \n                  \n                ', '', 'NBA 2K19 (PS4)2K Sports, Sports', '3', '17,528', '98,070']
# ['', 'NBA 2K19 (PS4)2K Sports, Sports']
# ['9', '\n                  \n                    \n                      \n                      Dead Island 2 (PS4)Deep Silver, Action\n                    \n                  \n                ', '', 'Dead Island 2 (PS4)Deep Silver, Action', '19', '176', '90,075']
# ['', 'Dead Island 2 (PS4)Deep Silver, Action']
# ['10', '\n                  \n                    \n                      \n                      Spyro Reignited Trilogy (PS4)Activision, Platform\n                    \n                  \n                ', '', 'Spyro Reignited Trilogy (PS4)Activision, Platform', '12', '2,541', '89,721']
# ['', 'Spyro Reignited Trilogy (PS4)Activision, Platform']
# ['11', '\n                  \n                    \n                      \n                      Call of Duty: Black Ops IIII (XOne)Activision, Shooter\n                    \n                  \n                ', '', 'Call of Duty: Black Ops IIII (XOne)Activision, Shooter', '7', '3,318', '79,006']
# ['', 'Call of Duty: Black Ops IIII (XOne)Activision, Shooter']
# ['12', '\n                  \n                    \n                      \n                      Super Mario Party (NS)Nintendo, Party\n                    \n                  \n                ', '', 'Super Mario Party (NS)Nintendo, Party', '6', '15,686', '56,562']
# ['', 'Super Mario Party (NS)Nintendo, Party']
# ['13', '\n                  \n                    \n                      \n                      Shadow of the Tomb Raider (PS4)Square Enix, Action-Adventure\n                    \n                  \n                ', '', 'Shadow of the Tomb Raider (PS4)Square Enix, Action-Adventure', '3', '4,655', '50,557']
# ['', 'Shadow of the Tomb Raider (PS4)Square Enix, Action-Adventure']
# ['14', '\n                  \n                    \n                      \n                      NBA 2K19 (XOne)2K Sports, Sports\n                    \n                  \n                ', '', 'NBA 2K19 (XOne)2K Sports, Sports', '2', '14,636', '48,703']
# ['', 'NBA 2K19 (XOne)2K Sports, Sports']
# ['15', '\n                  \n                    \n                      \n                      Final Fantasy VII Remake (PS4)Square Enix, Role-Playing\n                    \n                  \n                ', '', 'Final Fantasy VII Remake (PS4)Square Enix, Role-Playing', 'N/A', '47,543', '47,543']
# ['', 'Final Fantasy VII Remake (PS4)Square Enix, Role-Playing']
# ['16', '\n                  \n                    \n                      \n                      Kingdom Hearts III (XOne)Square Enix, Role-Playing\n                    \n                  \n                ', '', 'Kingdom Hearts III (XOne)Square Enix, Role-Playing', '23', '356', '44,582']
# ['', 'Kingdom Hearts III (XOne)Square Enix, Role-Playing']
# ['17', '\n                  \n                    \n                      \n                      Naruto to Boruto: Shinobi Striker (PS4)Bandai Namco Games, Action\n                    \n                  \n                ', '', 'Naruto to Boruto: Shinobi Striker (PS4)Bandai Namco Games, Action', '1', '922', '37,724']
# ['', 'Naruto to Boruto: Shinobi Striker (PS4)Bandai Namco Games, Action']
# ['18', '\n                  \n                    \n                      \n                      Mega Man 11 (NS)Capcom, Platform\n                    \n                  \n                ', '', 'Mega Man 11 (NS)Capcom, Platform', '6', '2,001', '37,561']
# ['', 'Mega Man 11 (NS)Capcom, Platform']
# ['19', '\n                  \n                    \n                      \n                      Fallout 76 (PS4)Bethesda Softworks, Role-Playing\n                    \n                  \n                ', '', 'Fallout 76 (PS4)Bethesda Softworks, Role-Playing', '12', '2,311', '37,249']
# ['', 'Fallout 76 (PS4)Bethesda Softworks, Role-Playing']
# ['20', '\n                  \n                    \n                      \n                      Resident Evil 2 (PS4)Capcom, Action-Adventure\n                    \n                  \n                ', '', 'Resident Evil 2 (PS4)Capcom, Action-Adventure', '22', '6,453', '36,910']
# ['', 'Resident Evil 2 (PS4)Capcom, Action-Adventure']
# ['21', "\n                  \n                    \n                      \n                      Pokémon: Let's Go, Pikachu! (NS)Nintendo, Role-Playing\n                    \n                  \n                ", '', "Pokémon: Let's Go, Pikachu! (NS)Nintendo, Role-Playing", '12', '5,620', '31,651']
# ['', "Pokémon: Let's Go, Pikachu! (NS)Nintendo, Role-Playing"]
# ['22', '\n                  \n                    \n                      \n                      Fallout 76 (XOne)Bethesda Softworks, Role-Playing\n                    \n                  \n                ', '', 'Fallout 76 (XOne)Bethesda Softworks, Role-Playing', '12', '2,011', '31,601']
# ['', 'Fallout 76 (XOne)Bethesda Softworks, Role-Playing']
# ['23', '\n                  \n                    \n                      \n                      Dark Souls: Remastered (NS)Bandai Namco Entertainment, Role-Playing\n                    \n                  \n                ', '', 'Dark Souls: Remastered (NS)Bandai Namco Entertainment, Role-Playing', '8', '977', '31,303']
# ['', 'Dark Souls: Remastered (NS)Bandai Namco Entertainment, Role-Playing']
# ['24', '\n                  \n                    \n                      \n                      Darksiders III (PS4)THQ Nordic, Action\n                    \n                  \n                ', '', 'Darksiders III (PS4)THQ Nordic, Action', '14', '755', '31,216']
# ['', 'Darksiders III (PS4)THQ Nordic, Action']
# ['25', '\n                  \n                    \n                      \n                      Naruto to Boruto: Shinobi Striker (XOne)Bandai Namco Games, Action\n                    \n                  \n                ', '', 'Naruto to Boruto: Shinobi Striker (XOne)Bandai Namco Games, Action', '1', '492', '30,560']
# ['', 'Naruto to Boruto: Shinobi Striker (XOne)Bandai Namco Games, Action']
# ['26', '\n                  \n                    \n                      \n                      SoulCalibur VI (PS4)Bandai Namco Games, Fighting\n                    \n                  \n                ', '', 'SoulCalibur VI (PS4)Bandai Namco Games, Fighting', '8', '2,441', '28,911']
# ['', 'SoulCalibur VI (PS4)Bandai Namco Games, Fighting']
# ['27', '\n                  \n                    \n                      \n                      Ace Combat 7: Skies Unknown (XOne)Bandai Namco Games, Shooter\n                    \n                  \n                ', '', 'Ace Combat 7: Skies Unknown (XOne)Bandai Namco Games, Shooter', '19', '65', '28,626']
# ['', 'Ace Combat 7: Skies Unknown (XOne)Bandai Namco Games, Shooter']
# ['28', '\n                  \n                    \n                      \n                      Yakuza Kiwami 2 (PS4)Sega, Action\n                    \n                  \n                ', '', 'Yakuza Kiwami 2 (PS4)Sega, Action', '1', '2,391', '27,693']
# ['', 'Yakuza Kiwami 2 (PS4)Sega, Action']
# ['29', '\n                  \n                    \n                      \n                      Ace Combat 7: Skies Unknown (PS4)Bandai Namco Games, Shooter\n                    \n                  \n                ', '', 'Ace Combat 7: Skies Unknown (PS4)Bandai Namco Games, Shooter', '19', '190', '26,902']
# ['', 'Ace Combat 7: Skies Unknown (PS4)Bandai Namco Games, Shooter']
# ['30', '\n                  \n                    \n                      \n                      Monster Hunter Double Cross (NS)Capcom, Action\n                    \n                  \n                ', '', 'Monster Hunter Double Cross (NS)Capcom, Action', '1', '5,642', '26,750']
# ['', 'Monster Hunter Double Cross (NS)Capcom, Action']
# ['31', '\n                  \n                    \n                      \n                      Darksiders III (XOne)THQ Nordic, Action\n                    \n                  \n                ', '', 'Darksiders III (XOne)THQ Nordic, Action', '14', '453', '25,306']
# ['', 'Darksiders III (XOne)THQ Nordic, Action']
# ['32', '\n                  \n                    \n                      \n                      Metro Exodus (PS4)Deep Silver, Shooter\n                    \n                  \n                ', '', 'Metro Exodus (PS4)Deep Silver, Shooter', '26', '790', '23,199']
# ['', 'Metro Exodus (PS4)Deep Silver, Shooter']
# ['33', '\n                  \n                    \n                      \n                      Metro Exodus (XOne)Deep Silver, Shooter\n                    \n                  \n                ', '', 'Metro Exodus (XOne)Deep Silver, Shooter', '26', '772', '22,646']
# ['', 'Metro Exodus (XOne)Deep Silver, Shooter']
# ['34', '\n                  \n                    \n                      \n                      Shadow of the Tomb Raider (XOne)Square Enix, Action-Adventure\n                    \n                  \n                ', '', 'Shadow of the Tomb Raider (XOne)Square Enix, Action-Adventure', '3', '2,581', '21,971']
# ['', 'Shadow of the Tomb Raider (XOne)Square Enix, Action-Adventure']
# ['35', '\n                  \n                    \n                      \n                      Dragon Quest XI (PS4)Square Enix, Role-Playing\n                    \n                  \n                ', '', 'Dragon Quest XI (PS4)Square Enix, Role-Playing', '2', '2,490', '21,946']
# ['', 'Dragon Quest XI (PS4)Square Enix, Role-Playing']
# ['36', '\n                  \n                    \n                      \n                      Metroid Prime 4 (NS)Nintendo, Action\n                    \n                  \n                ', '', 'Metroid Prime 4 (NS)Nintendo, Action', '19', '21,365', '21,365']
# ['', 'Metroid Prime 4 (NS)Nintendo, Action']
# ['37', '\n                  \n                    \n                      \n                      Spyro Reignited Trilogy (XOne)Activision, Platform\n                    \n                  \n                ', '', 'Spyro Reignited Trilogy (XOne)Activision, Platform', '12', '653', '20,474']
# ['', 'Spyro Reignited Trilogy (XOne)Activision, Platform']
# ['38', "\n                  \n                    \n                      \n                      Pokémon: Let's Go, Eevee! (NS)Nintendo, Role-Playing\n                    \n                  \n                ", '', "Pokémon: Let's Go, Eevee! (NS)Nintendo, Role-Playing", '12', '3,144', '18,817']
# ['', "Pokémon: Let's Go, Eevee! (NS)Nintendo, Role-Playing"]
# ['39', "\n                  \n                    \n                      \n                      Assassin's Creed Odyssey (PS4)Ubisoft, Action-Adventure\n                    \n                  \n                ", '', "Assassin's Creed Odyssey (PS4)Ubisoft, Action-Adventure", '6', '3,211', '16,656']
# ['', "Assassin's Creed Odyssey (PS4)Ubisoft, Action-Adventure"]
# ['40', '\n                  \n                    \n                      \n                      Valkyria Chronicles 4 (PS4)Sega, Role-Playing\n                    \n                  \n                ', '', 'Valkyria Chronicles 4 (PS4)Sega, Role-Playing', '5', '442', '15,404']
# ['', 'Valkyria Chronicles 4 (PS4)Sega, Role-Playing']
# ['1', 'PS4', 'Pro Evolution Soccer 2019', '158,619']
# ['2', 'NS', 'Monster Hunter Double Cross', '116,061']
# ['3', 'PS4', 'Yakuza Kiwami 2', '83,517']
# ['4', 'PS4', 'Naruto to Boruto: Shinobi Striker', '80,093']
# ['5', 'PS4', 'Madden NFL 19', '66,309']
# ['6', 'NS', 'Mario Kart 8 Deluxe', '63,695']
# ['7', 'PS4', 'F1 2018', '56,487']
# ['8', 'XOne', 'Madden NFL 19', '49,024']
# ['9', 'XOne', 'Naruto to Boruto: Shinobi Striker', '44,566']
# ['10', 'PS4', 'God of War (PS4)', '40,131']

# %%
import pandas as pd

dfs = pd.read_html('https://pythonprogramming.net/parsememcparseface/',header=0)
for df in dfs:
    print(df)
# Out:
#   Program Name  Internet Points    Kittens?
# 0       Python        932914021  Definitely
# 1       Pascal              532    Unlikely
# 2         Lisp             1522   Uncertain
# 3           D#               12    Possibly
# 4        Cobol                3         No.
# 5      Fortran            52124        Yes.
# 6      Haskell               24        lol.
