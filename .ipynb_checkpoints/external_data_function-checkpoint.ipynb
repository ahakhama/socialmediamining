# %% [markdown]
# # Scraping pre-order video game sales data
#
# The website www.vgchartz.com provides weekly pre-order data for video games by title and platform
# This script will programatically connect to the website via BeautifulSoup, download, transform, and store the data using pandas, urllib, and bs4.

# %%
#! usr/bin
# import required libraries and modules. 
import bs4 as bs
import urllib.request
import pandas as pd

# %% [markdown]
# ### This is an iteration on the previous one week's worth of data.
# - I'll start with establishing the structure of the website, which is as follows....
# - page of interest = www.vhcharts.com/preorders/43203/USA
# - where '43203' is a date serial representing a given week's end. For example, 43338 = week ending Sept 01 2018
# - Knowing that, I can implement a simple iterator to create a list with all 52 date serial's I'll need.

# %%
pages = []
x = 43345
for i in range(53):
    x -= 7
    list.append(x)
print(list)
# Out:
# [43338, 43331, 43324, 43317, 43310, 43303, 43296, 43289, 43282, 43275, 43268, 43261, 43254, 43247, 43240, 43233, 43226, 43219, 43212, 43205, 43198, 43191, 43184, 43177, 43170, 43163, 43156, 43149, 43142, 43135, 43128, 43121, 43114, 43107, 43100, 43093, 43086, 43079, 43072, 43065, 43058, 43051, 43044, 43037, 43030, 43023, 43016, 43009, 43002, 42995, 42988, 42981, 42974]

# %%
source = urllib.request.urlopen('http://www.vgchartz.com/preorders/43338/USA/')
soup = bs.BeautifulSoup(source, 'lxml')

# %% [markdown]
# for each webpage, I need to end up with a new data element - which could be an exported csv for each week.
#
# Put this all in a function...
# - Initialize an empty list, then iterate through the website's tables using BS4's "find_all" and a for loop:
# - pass in {}.format(variable) with week name for each source.
# - do i need to rename the variable?

# %%
data = []
for tr in soup.find_all(["tr"]):
    td = tr.find_all('td')
    row = [i.text for i in td]
    data.append(row)

# %%
# check to see what the data looks like. 
print(data[0:10])
# Out:
# [[], ['1', '\n\n\n\nSpider-Man (PS4) (PS4)Sony Interactive Entertainment, Action-Adventure\n\n\n', '', 'Spider-Man (PS4) (PS4)Sony Interactive Entertainment, Action-Adventure', '2', '13,142', '295,073'], ['', 'Spider-Man (PS4) (PS4)Sony Interactive Entertainment, Action-Adventure'], ['2', '\n\n\n\nSuper Smash Bros. (2018) (NS)Nintendo, Fighting\n\n\n', '', 'Super Smash Bros. (2018) (NS)Nintendo, Fighting', '15', '29,610', '272,702'], ['', 'Super Smash Bros. (2018) (NS)Nintendo, Fighting'], ['3', '\n\n\n\nRed Dead Redemption 2 (PS4)Rockstar Games, Action-Adventure\n\n\n', '', 'Red Dead Redemption 2 (PS4)Rockstar Games, Action-Adventure', '9', '6,474', '253,289'], ['', 'Red Dead Redemption 2 (PS4)Rockstar Games, Action-Adventure'], ['4', '\n\n\n\nRed Dead Redemption 2 (XOne)Rockstar Games, Action-Adventure\n\n\n', '', 'Red Dead Redemption 2 (XOne)Rockstar Games, Action-Adventure', '9', '3,330', '176,801'], ['', 'Red Dead Redemption 2 (XOne)Rockstar Games, Action-Adventure'], ['5', '\n\n\n\nKingdom Hearts III (PS4)Square Enix, Role-Playing\n\n\n', '', 'Kingdom Hearts III (PS4)Square Enix, Role-Playing', '23', '3,744', '169,742']]

# %% [markdown]
# The data is coming back, but it's got some issues we need to deal with:
#  - a blank header row
#  - lists of varying lengths
#  - several blank columns
# It looks like the website is using nested tables, so we'll have to take one more step to get this into a usable structure before putting it into a dataframe.
#
# The rows that look correct have seven elements, which we can easily parse out using list comprehension.

# %%
df = []
for i in data:
    if len(i) == 7:
        df.append(i)
        
print(df[0:10])
# Out:
# [['1', '\n\n\n\nSpider-Man (PS4) (PS4)Sony Interactive Entertainment, Action-Adventure\n\n\n', '', 'Spider-Man (PS4) (PS4)Sony Interactive Entertainment, Action-Adventure', '2', '13,142', '295,073'], ['2', '\n\n\n\nSuper Smash Bros. (2018) (NS)Nintendo, Fighting\n\n\n', '', 'Super Smash Bros. (2018) (NS)Nintendo, Fighting', '15', '29,610', '272,702'], ['3', '\n\n\n\nRed Dead Redemption 2 (PS4)Rockstar Games, Action-Adventure\n\n\n', '', 'Red Dead Redemption 2 (PS4)Rockstar Games, Action-Adventure', '9', '6,474', '253,289'], ['4', '\n\n\n\nRed Dead Redemption 2 (XOne)Rockstar Games, Action-Adventure\n\n\n', '', 'Red Dead Redemption 2 (XOne)Rockstar Games, Action-Adventure', '9', '3,330', '176,801'], ['5', '\n\n\n\nKingdom Hearts III (PS4)Square Enix, Role-Playing\n\n\n', '', 'Kingdom Hearts III (PS4)Square Enix, Role-Playing', '23', '3,744', '169,742'], ['6', '\n\n\n\nCall of Duty: Black Ops IIII (PS4)Activision, Shooter\n\n\n', '', 'Call of Duty: Black Ops IIII (PS4)Activision, Shooter', '7', '3,587', '139,810'], ['7', '\n\n\n\nDays Gone (PS4)Sony Interactive Entertainment, Action\n\n\n', '', 'Days Gone (PS4)Sony Interactive Entertainment, Action', '26', '420', '117,581'], ['8', '\n\n\n\nNBA 2K19 (PS4)2K Sports, Sports\n\n\n', '', 'NBA 2K19 (PS4)2K Sports, Sports', '3', '17,528', '98,070'], ['9', '\n\n\n\nDead Island 2 (PS4)Deep Silver, Action\n\n\n', '', 'Dead Island 2 (PS4)Deep Silver, Action', '19', '176', '90,075'], ['10', '\n\n\n\nSpyro Reignited Trilogy (PS4)Activision, Platform\n\n\n', '', 'Spyro Reignited Trilogy (PS4)Activision, Platform', '12', '2,541', '89,721']]

# %% [markdown]
# Now we a list of lists with seven elements each, and can turn this into a dataframe.
# I didn't want to waste a bunch of time trying to extract column headers, so we'll add those on transforming the data:

# %%
df = pd.DataFrame(df, columns = list(['Position', 'Name', 'Title', 'Type', 'Weeks to Launch', 'Weekly Total', 'Overall Total']))
#print(df)

#Name was a concatenation of several other columns, and title was blank so we'll drop those.  
df = df.drop(['Name', 'Title'], axis = 1)

# %% [markdown]
# I want to return just the title of the game, along with creating some dummy variables for the platform. There are plenty of other data points contained within this column (including the development studio) that we may want for another analysis.  For now, the features I'm extracting are the Title, Pre-order figures, and platform by week.

# %%
df['split_title'] = df['Type'].str.split('(').str[0]
df['ps4'] = df['Type'].str.contains('(PS4)', regex=False)
df['XOne'] = df['Type'].str.contains('(XOne)', regex=False)
df['Nintendo'] = df['Type'].str.contains('(NS)', regex=False)
df
# Out:
#    Position                                               Type  \
# 0         1  Spider-Man (PS4) (PS4)Sony Interactive Enterta...
# 1         2    Super Smash Bros. (2018) (NS)Nintendo, Fighting
# 2         3  Red Dead Redemption 2 (PS4)Rockstar Games, Act...
# 3         4  Red Dead Redemption 2 (XOne)Rockstar Games, Ac...
# 4         5  Kingdom Hearts III (PS4)Square Enix, Role-Playing
# 5         6  Call of Duty: Black Ops IIII (PS4)Activision, ...
# 6         7  Days Gone (PS4)Sony Interactive Entertainment,...
# 7         8                    NBA 2K19 (PS4)2K Sports, Sports
# 8         9             Dead Island 2 (PS4)Deep Silver, Action
# 9        10  Spyro Reignited Trilogy (PS4)Activision, Platform
# 10       11  Call of Duty: Black Ops IIII (XOne)Activision,...
# 11       12              Super Mario Party (NS)Nintendo, Party
# 12       13  Shadow of the Tomb Raider (PS4)Square Enix, Ac...
# 13       14                   NBA 2K19 (XOne)2K Sports, Sports
# 14       15  Final Fantasy VII Remake (PS4)Square Enix, Rol...
# 15       16  Kingdom Hearts III (XOne)Square Enix, Role-Pla...
# 16       17  Naruto to Boruto: Shinobi Striker (PS4)Bandai ...
# 17       18                   Mega Man 11 (NS)Capcom, Platform
# 18       19   Fallout 76 (PS4)Bethesda Softworks, Role-Playing
# 19       20      Resident Evil 2 (PS4)Capcom, Action-Adventure
# 20       21  Pokémon: Let's Go, Pikachu! (NS)Nintendo, Role...
# 21       22  Fallout 76 (XOne)Bethesda Softworks, Role-Playing
# 22       23  Dark Souls: Remastered (NS)Bandai Namco Entert...
# 23       24             Darksiders III (PS4)THQ Nordic, Action
# 24       25  Naruto to Boruto: Shinobi Striker (XOne)Bandai...
# 25       26   SoulCalibur VI (PS4)Bandai Namco Games, Fighting
# 26       27  Ace Combat 7: Skies Unknown (XOne)Bandai Namco...
# 27       28                  Yakuza Kiwami 2 (PS4)Sega, Action
# 28       29  Ace Combat 7: Skies Unknown (PS4)Bandai Namco ...
# 29       30     Monster Hunter Double Cross (NS)Capcom, Action
# ..      ...                                                ...
# 50       11  Call of Duty: Black Ops IIII (XOne)Activision,...
# 51       12              Super Mario Party (NS)Nintendo, Party
# 52       13  Shadow of the Tomb Raider (PS4)Square Enix, Ac...
# 53       14                   NBA 2K19 (XOne)2K Sports, Sports
# 54       15  Final Fantasy VII Remake (PS4)Square Enix, Rol...
# 55       16  Kingdom Hearts III (XOne)Square Enix, Role-Pla...
# 56       17  Naruto to Boruto: Shinobi Striker (PS4)Bandai ...
# 57       18                   Mega Man 11 (NS)Capcom, Platform
# 58       19   Fallout 76 (PS4)Bethesda Softworks, Role-Playing
# 59       20      Resident Evil 2 (PS4)Capcom, Action-Adventure
# 60       21  Pokémon: Let's Go, Pikachu! (NS)Nintendo, Role...
# 61       22  Fallout 76 (XOne)Bethesda Softworks, Role-Playing
# 62       23  Dark Souls: Remastered (NS)Bandai Namco Entert...
# 63       24             Darksiders III (PS4)THQ Nordic, Action
# 64       25  Naruto to Boruto: Shinobi Striker (XOne)Bandai...
# 65       26   SoulCalibur VI (PS4)Bandai Namco Games, Fighting
# 66       27  Ace Combat 7: Skies Unknown (XOne)Bandai Namco...
# 67       28                  Yakuza Kiwami 2 (PS4)Sega, Action
# 68       29  Ace Combat 7: Skies Unknown (PS4)Bandai Namco ...
# 69       30     Monster Hunter Double Cross (NS)Capcom, Action
# 70       31            Darksiders III (XOne)THQ Nordic, Action
# 71       32             Metro Exodus (PS4)Deep Silver, Shooter
# 72       33            Metro Exodus (XOne)Deep Silver, Shooter
# 73       34  Shadow of the Tomb Raider (XOne)Square Enix, A...
# 74       35     Dragon Quest XI (PS4)Square Enix, Role-Playing
# 75       36               Metroid Prime 4 (NS)Nintendo, Action
# 76       37  Spyro Reignited Trilogy (XOne)Activision, Plat...
# 77       38  Pokémon: Let's Go, Eevee! (NS)Nintendo, Role-P...
# 78       39  Assassin's Creed Odyssey (PS4)Ubisoft, Action-...
# 79       40      Valkyria Chronicles 4 (PS4)Sega, Role-Playing
#
#    Weeks to Launch Weekly Total Overall Total  \
# 0                2       13,142       295,073
# 1               15       29,610       272,702
# 2                9        6,474       253,289
# 3                9        3,330       176,801
# 4               23        3,744       169,742
# 5                7        3,587       139,810
# 6               26          420       117,581
# 7                3       17,528        98,070
# 8               19          176        90,075
# 9               12        2,541        89,721
# 10               7        3,318        79,006
# 11               6       15,686        56,562
# 12               3        4,655        50,557
# 13               2       14,636        48,703
# 14             N/A       47,543        47,543
# 15              23          356        44,582
# 16               1          922        37,724
# 17               6        2,001        37,561
# 18              12        2,311        37,249
# 19              22        6,453        36,910
# 20              12        5,620        31,651
# 21              12        2,011        31,601
# 22               8          977        31,303
# 23              14          755        31,216
# 24               1          492        30,560
# 25               8        2,441        28,911
# 26              19           65        28,626
# 27               1        2,391        27,693
# 28              19          190        26,902
# 29               1        5,642        26,750
# ..             ...          ...           ...
# 50               7        3,318        79,006
# 51               6       15,686        56,562
# 52               3        4,655        50,557
# 53               2       14,636        48,703
# 54             N/A       47,543        47,543
# 55              23          356        44,582
# 56               1          922        37,724
# 57               6        2,001        37,561
# 58              12        2,311        37,249
# 59              22        6,453        36,910
# 60              12        5,620        31,651
# 61              12        2,011        31,601
# 62               8          977        31,303
# 63              14          755        31,216
# 64               1          492        30,560
# 65               8        2,441        28,911
# 66              19           65        28,626
# 67               1        2,391        27,693
# 68              19          190        26,902
# 69               1        5,642        26,750
# 70              14          453        25,306
# 71              26          790        23,199
# 72              26          772        22,646
# 73               3        2,581        21,971
# 74               2        2,490        21,946
# 75              19       21,365        21,365
# 76              12          653        20,474
# 77              12        3,144        18,817
# 78               6        3,211        16,656
# 79               5          442        15,404
#
#                            split_title    ps4   XOne  Nintendo
# 0                          Spider-Man    True  False     False
# 1                   Super Smash Bros.   False  False      True
# 2               Red Dead Redemption 2    True  False     False
# 3               Red Dead Redemption 2   False   True     False
# 4                  Kingdom Hearts III    True  False     False
# 5        Call of Duty: Black Ops IIII    True  False     False
# 6                           Days Gone    True  False     False
# 7                            NBA 2K19    True  False     False
# 8                       Dead Island 2    True  False     False
# 9             Spyro Reignited Trilogy    True  False     False
# 10       Call of Duty: Black Ops IIII   False   True     False
# 11                  Super Mario Party   False  False      True
# 12          Shadow of the Tomb Raider    True  False     False
# 13                           NBA 2K19   False   True     False
# 14           Final Fantasy VII Remake    True  False     False
# 15                 Kingdom Hearts III   False   True     False
# 16  Naruto to Boruto: Shinobi Striker    True  False     False
# 17                        Mega Man 11   False  False      True
# 18                         Fallout 76    True  False     False
# 19                    Resident Evil 2    True  False     False
# 20        Pokémon: Let's Go, Pikachu!   False  False      True
# 21                         Fallout 76   False   True     False
# 22             Dark Souls: Remastered   False  False      True
# 23                     Darksiders III    True  False     False
# 24  Naruto to Boruto: Shinobi Striker   False   True     False
# 25                     SoulCalibur VI    True  False     False
# 26        Ace Combat 7: Skies Unknown   False   True     False
# 27                    Yakuza Kiwami 2    True  False     False
# 28        Ace Combat 7: Skies Unknown    True  False     False
# 29        Monster Hunter Double Cross   False  False      True
# ..                                 ...    ...    ...       ...
# 50       Call of Duty: Black Ops IIII   False   True     False
# 51                  Super Mario Party   False  False      True
# 52          Shadow of the Tomb Raider    True  False     False
# 53                           NBA 2K19   False   True     False
# 54           Final Fantasy VII Remake    True  False     False
# 55                 Kingdom Hearts III   False   True     False
# 56  Naruto to Boruto: Shinobi Striker    True  False     False
# 57                        Mega Man 11   False  False      True
# 58                         Fallout 76    True  False     False
# 59                    Resident Evil 2    True  False     False
# 60        Pokémon: Let's Go, Pikachu!   False  False      True
# 61                         Fallout 76   False   True     False
# 62             Dark Souls: Remastered   False  False      True
# 63                     Darksiders III    True  False     False
# 64  Naruto to Boruto: Shinobi Striker   False   True     False
# 65                     SoulCalibur VI    True  False     False
# 66        Ace Combat 7: Skies Unknown   False   True     False
# 67                    Yakuza Kiwami 2    True  False     False
# 68        Ace Combat 7: Skies Unknown    True  False     False
# 69        Monster Hunter Double Cross   False  False      True
# 70                     Darksiders III   False   True     False
# 71                       Metro Exodus    True  False     False
# 72                       Metro Exodus   False   True     False
# 73          Shadow of the Tomb Raider   False   True     False
# 74                    Dragon Quest XI    True  False     False
# 75                    Metroid Prime 4   False  False      True
# 76            Spyro Reignited Trilogy   False   True     False
# 77          Pokémon: Let's Go, Eevee!   False  False      True
# 78           Assassin's Creed Odyssey    True  False     False
# 79              Valkyria Chronicles 4    True  False     False
#
# [80 rows x 9 columns]

# %% [markdown]
# Now I need to figure out how to get 52 weeks worth of data.
